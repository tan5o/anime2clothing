# %% [markdown]
# # Anime2Clothing
# Pytorch official implementation of **Anime to Real Clothing: Cosplay Costume Generation via Image-to-Image Translation**.
# ![purpose_of_paper.png](data:image/png;base64,...)

# %% [markdown]
# ## Prerequisites
# - Anaconda 3
# - Python 3
# - PyTorch
# - CPU or NVIDIA GPU + CUDA CuDNN
#
# ## Note
# We recommend using an anime character image with a simple background as the input image.

# %%
# !git clone https://github.com/tan5o/anime2clothing
# Out:
# fatal: destination path 'anime2clothing' already exists and is not an empty directory.

# %%
cd anime2clothing/
# Out:
# /content/anime2clothing

# %%
# !mkdir input_dir
# !mkdir output_dir
# Out:
# mkdir: cannot create directory ‘input_dir’: File exists
# mkdir: cannot create directory ‘output_dir’: File exists

# %% [markdown]
# # DEMO

# %%
from google.colab import files
import shutil

files = files.upload()
file_name = list(files.keys())[0]

shutil.move(file_name, 'input_dir/')
# Out:
#      <input type="file" id="files-244a8cc2-8ea9-4955-84c3-17ce2d732d76" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-244a8cc2-8ea9-4955-84c3-17ce2d732d76">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2020-08-27_10h52_00.png to 2020-08-27_10h52_00.png
# 'input_dir/2020-08-27_10h52_00.png'

# %%
# !python test.py --model_path models/pretrained_unet_20200122.pth --input_dir input_dir/ --output_dir output_dir/
# Out:
# Namespace(input_dir='input_dir/', model_path='models/pretrained_unet_20200122.pth', output_dir='output_dir/')
# found 3 files
# 0/3
# Traceback (most recent call last):
#   File "test.py", line 36, in <module>
#     img = Image.open(os.path.join(opt.input_dir, f))
#   File "/usr/local/lib/python3.6/dist-packages/PIL/Image.py", line 2809, in open
#     fp = builtins.open(filename, "rb")
# IsADirectoryError: [Errno 21] Is a directory: 'input_dir/.ipynb_checkpoints'

# %%
from IPython.display import Image, display_png
display_png(Image('output_dir/' + file_name))

# %% [markdown]
# The left half shows the input image and the right half shows the output image.
